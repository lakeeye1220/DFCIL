# %%
# imagenet-1k 5task

rdfcil = [
    78.34, 49.44, 32.41, 26.03, 19.53
]
ours = [
    	78.25,63.13,53.33,48.04,42.52
]

# %%
import matplotlib.pyplot as plt
import numpy as np
# visualize line graph
x = np.arange(1, 6)
plt.plot(x, rdfcil, label='RDFCIL', marker='s', linestyle=':', linewidth=2, color='blue')
plt.plot(x, ours, label='ISCF (Ours)', marker='o', linestyle='--', linewidth=2, color='red')

plt.xlabel('Incremental steps (T)', fontsize=16)
plt.ylabel('Accuracy (%)', fontsize=16)
# plt.title('Incremental Accuracy (%) - ImageNet-1K')
plt.legend(fontsize=15)
plt.grid(True)
plt.xticks(np.arange(1,6),fontsize=14)
plt.yticks(np.arange(20,80,10),fontsize=14)
plt.savefig('incremental_acc_imagenet-1k_5t.pdf', bbox_inches='tight')

# %%
# imagenet-1k 10task

rdfcil = [
    78.12,61.88,47.77,39.77,30.62,23.86,20.75,16.04,12.88,12.15
]
ours = [
    	79.14,66.74,56.23,49.88,43.81,39.17,35.83,32.75,30.3,27.07
]

# %%
import matplotlib.pyplot as plt
import numpy as np
# visualize line graph
x = np.arange(1, len(ours)+1)
plt.plot(x, rdfcil, label='RDFCIL', marker='s', linestyle=':', linewidth=2, color='blue')
plt.plot(x, ours, label='ISCF (Ours)', marker='o', linestyle='--', linewidth=2, color='red')

plt.xlabel('Incremental steps (T)', fontsize=16)
plt.ylabel('Accuracy (%)', fontsize=16)
# plt.title('Incremental Accuracy (%) - ImageNet-1K')
plt.legend(fontsize=15)
plt.grid(True)
plt.xticks(np.arange(1,len(ours)+1),fontsize=14)
plt.yticks(np.arange(20,90,10),fontsize=14)
plt.savefig('incremental_acc_imagenet-1k_10t.pdf', bbox_inches='tight')

# %%
# imagenet-1k 10task

rdfcil = [
    82.52,65.94,57.41,50.49,42.11,35.5,28.77,25.65,20.94,18.42,14.99,14.14,12.6,12.43,11.18,9.66,8.32,7.85,7.69,7.25
]
ours = [
    	82.16,67.66,60.65,54.57,48.37,43.03,37.61,34.92,31.94,28.98,25.93,24.04,22.56,21.25,20.57,19.78,19.53,18.64,17.98,17.44
]

# %%
import matplotlib.pyplot as plt
import numpy as np
# visualize line graph
x = np.arange(1, len(ours)+1)
plt.plot(x, rdfcil, label='RDFCIL', marker='s', linestyle=':', linewidth=2, color='blue')
plt.plot(x, ours, label='ISCF (Ours)', marker='o', linestyle='--', linewidth=2, color='red')

plt.xlabel('Incremental steps (T)', fontsize=16)
plt.ylabel('Accuracy (%)', fontsize=16)
# plt.title('Incremental Accuracy (%) - ImageNet-1K')
plt.legend(fontsize=15)
plt.grid(True)
plt.xticks(np.arange(1,len(ours)+1),fontsize=14)
plt.yticks(np.arange(0,90,10),fontsize=14)
plt.savefig('incremental_acc_imagenet-1k_20t.pdf', bbox_inches='tight')

# %%
# imagenet-100 5task
import numpy as np
name= ['abd','base','bic','deepinv','eeil','lwf','lwf_coreset','lwf_mc','rehearsal','rdfcil','ours']
data=[[76.9,82.3,82.3,82.3,82.3,82.3,82.3,78.1,82.3,87.2,87.5],
[67.75,42.95,66.75,44.95,68.35,43.4,68.95,66.1,63.7,76.1,74.25],
[63.46666,29.599999,64.666,32.66666,59.666,29.5,59.2333,61.53333,50.266666,65.2,65.47],
[58.9999,22.8,60.125,26,51.5,23.4,50.075,58.175,42,56.88,61.42],
[52.339999,18.38,56.98,21.58,47.239999,19.96,41.48,54.779999,34.56,49.44,54.64]]

data = np.array(data)
a = data.T

# visualize line graph
x = np.arange(1,a.shape[1]+1)

plt.plot(x, a[1], label='Base', marker='<', linestyle='--', linewidth=2, color='cyan')
plt.plot(x, a[8], label='Rehearsal', marker='d', linestyle='-.', linewidth=2, color='gray')
plt.plot(x, a[6], label='LwF_coreset', marker='*', linestyle='--', linewidth=2, color='brown')
plt.plot(x, a[7], label='LwF_mc', marker='h', linestyle='-', linewidth=2, color='pink')
plt.plot(x, a[4], label='EEIL', marker='v', linestyle='-.', linewidth=2, color='orange')
plt.plot(x, a[2], label='BIC', marker='x', linestyle='-', linewidth=2, color='green')
plt.plot(x, a[5], label='LwF', marker='p', linestyle=':', linewidth=2, color='black')
plt.plot(x, a[3], label='DeepInv', marker='^', linestyle='-.', linewidth=2, color='purple')
plt.plot(x, a[0], label='ABD', marker='s', linestyle=':', linewidth=2, color='magenta')
plt.plot(x, a[9], label='RDFCIL', marker='>', linestyle='-', linewidth=2, color='blue')
plt.plot(x, a[10], label='ISCF (Ours)', marker='o', linewidth=3, color='red')

plt.xlabel('Incremental steps (T)', fontsize=16)
plt.ylabel('Accuracy (%)', fontsize=16)
# set legend outside of graph
plt.legend(fontsize=15, loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.xticks(np.arange(1,6),fontsize=14)
# plt.yticks(np.arange(0,100,10),fontsize=14)
plt.savefig('incremental_acc_imagenet-100_5task.pdf', bbox_inches='tight')

# %%
# imagenet-100 10task
name = ['abd','base','bic','deepinv','eeil','lwf','lwf_coreset','lwf_mc','rehearsal','rdfcil','ours']

data=[[86.6,90.6,81.4,81.4,81.4,81.4,81.4,76.8,81.4,87.2,88],
[66,40.4,65.7,43.6,65.7,42.8,73,64.5,72.8,76.5,79],
[63.7999,30.06666667,60.533,32.06666667,60.533,30.33333333,64,56.06666667,58.8,70.73,71.87],
[60.45,22.65,57.7,23.25,57.7,21.9,54.65,53.9,50.4,62.6,64.3],
[56.63999,17.04,54.72,18.88,54.72,18.28,47.44,49.28,42.16,54.36,57.32],
[56.36666,14.53333333,52.5,16.73333333,52.5,16,40.46666667,48.53333333,36.9,50.5,53.57],
[54.28,12.51428571,51.31428,15.62857143,51.31428,13.77142857,37.08571429,48.51428571,34.8,47.46,51.49],
[48.5,11.025,46.55,13.2,46.55,12.25,31.4,46.225,28.825,45.95,48.12],
[44,9.444444444,43.75555,12.53333333,43.7555,10.64444444,27.84444444,43.15555556,25.26666667,43.58,47.84],
[39.67999,8.48,43.14,11.42,43.14,10.34,23.96,41.38,21.68,40.7,45.18]]

data = np.array(data)
a = data.T

# visualize line graph
x = np.arange(1,a.shape[1]+1)

plt.plot(x, a[1], label='Base', marker='<', linestyle='--', linewidth=2, color='cyan')
plt.plot(x, a[8], label='Rehearsal', marker='d', linestyle='-.', linewidth=2, color='gray')
plt.plot(x, a[6], label='LwF_coreset', marker='*', linestyle='--', linewidth=2, color='brown')
plt.plot(x, a[7], label='LwF_mc', marker='h', linestyle='-', linewidth=2, color='pink')
plt.plot(x, a[4], label='EEIL', marker='v', linestyle='-.', linewidth=2, color='orange')
plt.plot(x, a[2], label='BIC', marker='x', linestyle='-', linewidth=2, color='green')
plt.plot(x, a[5], label='LwF', marker='p', linestyle=':', linewidth=2, color='black')
plt.plot(x, a[3], label='DeepInv', marker='^', linestyle='-.', linewidth=2, color='purple')
plt.plot(x, a[0], label='ABD', marker='s', linestyle=':', linewidth=2, color='magenta')
plt.plot(x, a[9], label='RDFCIL', marker='>', linestyle='-', linewidth=2, color='blue')
plt.plot(x, a[10], label='ISCF (Ours)', marker='o', linewidth=3, color='red')

plt.xlabel('Incremental steps (T)', fontsize=16)
plt.ylabel('Accuracy (%)', fontsize=16)
# set legend outside of graph
plt.legend(fontsize=15, loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.xticks(np.arange(1,11),fontsize=14)
# plt.yticks(np.arange(0,100,10),fontsize=14)
plt.savefig('incremental_acc_imagenet-100_10task.pdf', bbox_inches='tight')

# %%
# imagenet-100 10task
import numpy as np
import matplotlib.pyplot as plt
name = ['abd','base','bic','deepinv','eeil','lwf','lwf_coreset','lwf_mc','rehearsal','rdfcil','ours']

data=[
[84,88,86.4,88,84,88,86.4,82,88,88.8,89.6],
[55.6,42.8,71.6,47,73.2,43,81.6,64.4,80.4,75.8,77.2],
[47.73333333,28.8,61.33333333,31.33333333,64.8,28.93333333,73.06666667,53.86666667,67.46666667,71.73,70.27],
[45.9,21.8,56.7,24,57.4,21.8,66.5,49.4,61.9,62.6,64.9],
[44.72,18.64,54,19.28,52.56,18.16,62.88,48.96,54.32,56.16,60.48],
[42.26666667,15.2,53.46666667,18.33333333,47.73333333,15.4,53.73333333,41.73333333,45.46666667,54.27,57.27],
[42.74285714,13.37142857,48.34285714,13.25714286,47.65714286,13.08571429,49.88571429,40.62857143,38.17142857,49.89,53.31],
[40.7,11.3,47,12.5,45.05,11.1,43.9,38.75,33.5,46.8,49.2],
[37.55555556,10.4,41.64444444,10.97777778,40.22222222,10.44444444,38.71111111,36.97777778,30.57777778,43.38,45.78],
[36.4,9.08,37.88,10.2,39.88,9.12,36.64,35,28.08,38.48,43],
[36.14545455,8.763636364,33.85454545,9.272727273,40.61818182,8.872727273,34.90909091,35.16363636,28.50909091,38.55,43.09],
[36.13333333,7.333333333,30.6,9.466666667,39.36666667,7.366666667,33.86666667,32.56666667,24.3,36.33,40.93],
[34.21538462,7.415384615,26.92307692,8.338461538,38.30769231,7.415384615,30.52307692,30.06153846,25.90769231,34.06,39.2],
[33.34285714,6.571428571,25.54285714,7.485714286,38.97142857,6.828571429,30.71428571,30,20.8,34.17,38.26],
[30.16,6.4,28.85333333,6.826666667,35.28,6.48,26.58666667,27.78666667,19.81333333,34.16,37.65],
[28.475,5.95,27,6.6,35.525,5.875,25.775,28.475,18.725,32.88,36.95],
[24.8,5.623529412,26.16470588,7.294117647,35.41176471,5.647058824,23.24705882,28.14117647,18.11764706,31.2,35.95],
[21.06666667,5.311111111,26.33333333,5.955555556,32.6,5.511111111,19.88888889,26.8,16.6,30.04,35.22],
[19.2,4.947368421,23.03157895,6.210526316,33.45263158,5.052631579,18.16842105,26.37894737,16.82105263,29.01,33.79],
[16.32,4.62,20.66,5.72,31.22,4.76,16.06,25.64,14.74,28.54,32.9],
]

data = np.array(data)
a = data.T

# visualize line graph
x = np.arange(1,a.shape[1]+1)

plt.plot(x, a[1], label='Base', marker='<', linestyle='--', linewidth=2, color='cyan')
plt.plot(x, a[8], label='Rehearsal', marker='d', linestyle='-.', linewidth=2, color='gray')
plt.plot(x, a[6], label='LwF_coreset', marker='*', linestyle='--', linewidth=2, color='brown')
plt.plot(x, a[7], label='LwF_mc', marker='h', linestyle='-', linewidth=2, color='pink')
plt.plot(x, a[4], label='EEIL', marker='v', linestyle='-.', linewidth=2, color='orange')
plt.plot(x, a[2], label='BIC', marker='x', linestyle='-', linewidth=2, color='green')
plt.plot(x, a[5], label='LwF', marker='p', linestyle=':', linewidth=2, color='black')
plt.plot(x, a[3], label='DeepInv', marker='^', linestyle='-.', linewidth=2, color='purple')
plt.plot(x, a[0], label='ABD', marker='s', linestyle=':', linewidth=2, color='magenta')
plt.plot(x, a[9], label='RDFCIL', marker='>', linestyle='-', linewidth=2, color='blue')
plt.plot(x, a[10], label='ISCF (Ours)', marker='o', linewidth=3, color='red')

plt.xlabel('Incremental steps (T)', fontsize=16)
plt.ylabel('Accuracy (%)', fontsize=16)
# set legend outside of graph
plt.legend(fontsize=15, loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.xticks(np.arange(1,21),fontsize=14)
# plt.yticks(np.arange(0,100,10),fontsize=14)
plt.savefig('incremental_acc_imagenet-100_20task.pdf', bbox_inches='tight')
